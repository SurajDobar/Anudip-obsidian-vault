# %%
#builtin modules
import math
# from math import sqrt
result=math.sqrt(16)
# result=sqrt(16)
print(result)
# Out:
# 4.0

# %%
import datetime as dt
curtime=dt.datetime.now()
print(curtime)
# Out:
# 2026-07-30 16:31:50.023204

# %%
from random import *
result=randint(1, 10)
print(result)
# Out:
# 10

# %%
#access specific custom module 

import mymodule
print(mymodule.addition(5, 10))
print(mymodule.subtraction(10, 5))
print(mymodule.display("Anudip"))
# Out:
# 15
# 5
# Hello Anudip
# None

# %%
# access custom module using alias name
import mymodule as mm
print(mm.addition(5, 10))
print(mm.subtraction(10, 5))
print(mm.multiplication(5, 10))
# Out:
# 15
# 5
# 50

# %%
from display import Myclass
obj=Myclass()
print(obj.display("Anudip"))
# Out:
# Hello Anudip!

# %%
import os
print(dir(os)) #dir is used for listing all the methods and attributes of a module
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk_symlinks_as_files', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsy
# ...

# %%
import os 
#creating new directory     
os.mkdir("sample")
#change current working directory
os.chdir("sample")

#creating new file
with open("sample.txt", "w") as f:
    f.write("This is a sample file.")
#get the absolute path of the file 
print(os.path.abspath("sample.txt"))
# Out:
# d:\Anudip\AdvancePython\day6\sample\sample.txt

# %%
import sys,datetime
print(sys.path)
print(sys.platform)
print(sys.version)
print(dir(sys))
print(dir(datetime))
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\python312.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0', '', 'C:\\Users\\i7650\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\\Lib\\site-packages']
# win32
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# ...
